# %% [raw]
# ## EDA-1

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Cardiotocographic.csv")

# %%
data
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %% [raw]
# # LB, DS, DP, MLTV, WIDTH, TENDENCY, NSP - Has only 2105 records and AC has 2106 records indicating the presence of na values. All 14 are float varaibles.

# %%
data.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %%
# Identifying missing values

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
# Dealing with missing values by replacing

# %%
LB_Missing_na_with_mean = data["LB"].fillna(data["LB"].mean(), inplace=True)
AC_Missing_na_with_mean = data["AC"].fillna(data["AC"].mean(), inplace=True)
DS_Missing_na_with_mean = data["DS"].fillna(data["DS"].mean(), inplace=True)
DP_Missing_na_with_mean = data["DP"].fillna(data["DP"].mean(), inplace=True)
MLTV_Missing_na_with_mean = data["MLTV"].fillna(data["MLTV"].mean(), inplace=True)
Width_Missing_na_with_mean = data["Width"].fillna(data["Width"].mean(), inplace=True)
Tendency_Missing_na_with_mean = data["Tendency"].fillna(data["Tendency"].mean(), inplace=True)
NSP_Missing_na_with_mean = data["NSP"].fillna(data["NSP"].mean(), inplace=True)

# %%
data.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %%
sn.boxplot(data['LB'],orient="h");

# %%
Q1 = data["LB"].quantile(0.25)
Q3 = data["LB"].quantile(0.75)
print("LB quantile:",Q1, Q3)
# Out:
# LB quantile: 126.0 140.0

# %%
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
print("IQR:",IQR)
print("lower_bound:",lower_bound)
print("upper_bound:",upper_bound)
# Out:
# IQR: 14.0
# lower_bound: 105.0
# upper_bound: 161.0

# %%
data[data["LB"]<lower_bound]
# Out:
#              LB        AC        FM        UC        DL        DS        DP  \
# 134   52.000000  0.001590  0.000000  0.029851  0.000000  0.000000  0.000003
# 785   52.000000  0.000834  0.013344  0.000000  0.000000  0.000000  0.000000
# 1027  51.842487  0.009485  0.000000  0.005420  0.002710  0.000005  0.000000
# 1834  52.188547  0.000000  0.001043  0.003128  0.007299  0.000000  0.000000
#
#       ASTV  MSTV  ALTV  MLTV      Width  Tendency  NSP
# 134   58.0   0.5   0.0   7.9   44.00000       1.0  1.0
# 785   53.0   0.7   8.0  12.0   77.00000       1.0  1.0
# 1027 -63.0   2.5   0.0   3.9   98.00000       0.0  1.0
# 1834  61.0   1.4   0.0  10.0  105.40169       1.0  1.0

# %%
data[data["LB"]>upper_bound]
# Out:
#          LB        AC        FM        UC        DL        DS   DP       ASTV  \
# 411   214.0  0.000000  0.000000  0.001595  0.001595  0.000000  0.0  71.000000
# 610   214.0  0.002469  0.002469  0.002469  0.000000  0.000004  0.0  35.000000
# 612   214.0  0.005181  0.012953  0.002591  0.000000  0.000000  0.0  39.442226
# 1103  214.0  0.006972  0.000000  0.002960  0.000000  0.000000  0.0  19.000000
# 1406  214.0  0.005068  0.000000  0.001689  0.000000  0.000000  0.0  46.000000
# 1504  214.0  0.006189  0.000000  0.006189  0.000000  0.000000  0.0  38.000000
#
#           MSTV  ALTV  MLTV  Width  Tendency     NSP
# 411   0.300000  17.0   5.8   15.0       0.0  2.0000
# 610   1.798149   0.0  24.7  118.0       1.0  1.0000
# 612   1.600000   0.0  10.0  136.0       0.0  0.9912
# 1103  2.300000   0.0  12.1   53.0       0.0  1.0000
# 1406  0.800000   0.0   8.6   67.0       1.0  1.0000
# 1504  1.000000   0.0   8.1   53.0       0.0  1.0000

# %%
print(data["LB"].quantile(0.05))
print(data["LB"].quantile(0.95))
# Out:
# 119.0
# 149.0

# %%
# treatment of outliers by replacing the values
# the values lesser than 119 are replaced by 119 and 
# the values greater than 149 are replaced by 149.
data["LB"] = np.where(data["LB"]<119,119,data["LB"])
data["LB"] = np.where(data["LB"]>149,149,data["LB"])

# %%
sn.boxplot(data["LB"],orient = "h")
# Out:
# <Axes: >

# %%
sn.boxplot(data["AC"],orient = "h")
# Out:
# <Axes: >

# %%
Q1 = data["AC"].quantile(0.25)
Q3 = data["AC"].quantile(0.75)
print("AC quantile:",Q1,"and", Q3)
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
print("IQR = Q3-Q1:",IQR)
print("lower_bound:",lower_bound)
print("upper_bound:",upper_bound)
# Out:
# AC quantile: 0.0 and 0.0056061275
# IQR = Q3-Q1: 0.0056061275
# lower_bound: -0.00840919125
# upper_bound: 0.01401531875

# %%
data[data["AC"]<lower_bound]
# Out:
#          LB        AC        FM        UC        DL   DS        DP       ASTV  \
# 23    128.0 -0.019284  0.000000  0.000000  0.000000  0.0  0.000000  80.000000
# 157   123.0 -0.019284  0.000000  0.006400  0.000000  0.0  0.000000  37.927549
# 681   140.0 -0.019284  0.003191  0.004255  0.000000  0.0  0.000000  34.000000
# 1752  134.0 -0.019284  0.001096  0.001096  0.003289  0.0  0.003289  61.000000
#
#       MSTV  ALTV  MLTV  Width  Tendency       NSP
# 23     0.5   0.0   6.8   16.0   1.00000  3.000000
# 157    0.9  13.0   8.0   24.0   0.00000  1.000000
# 681    2.9   0.0  40.8  114.0   1.00000  0.984834
# 1752   1.8   0.0   0.0  118.0  -1.00594  3.000000

# %%
data[data["AC"]>upper_bound]
# Out:
#               LB        AC        FM        UC        DL        DS        DP  \
# 8     122.000000  0.038567  0.000000  0.001517  0.000000  0.000000  0.000000
# 83    145.000000  0.014706  0.008403  0.002101  0.000000  0.000000  0.000000
# 85    145.000000  0.014230  0.025873  0.001294  0.000000  0.000000  0.000000
# 116   133.343598  0.038567  0.000000  0.006993  0.002331  0.000003  0.000175
# 181   138.000000  0.017241  0.000000  0.005305  0.000000  0.000000  0.000000
# 496   130.000000  0.014178  0.091743  0.000938  0.000000  0.000000  0.000000
# 497   130.000000  0.015552  0.083981  0.001555 -0.000026  0.000000  0.000000
# 498   130.000000  0.015258  0.115023  0.000000  0.000000  0.000000  0.000000
# 500   131.000000  0.014178  0.015013  0.000834  0.000000  0.000000  0.000000
# 501   131.000000  0.014726  0.017403  0.001339  0.000000  0.000000  0.000000
# 526   142.000000  0.015013  0.062552  0.001668  0.000834  0.000000  0.000000
# ...

# %%
print(data["AC"].quantile(0.05))
print(data["AC"].quantile(0.95))
# Out:
# 0.0
# 0.011059007499999999

# %%
# treatment of outliers by replacing the values
# the values lesser than 0 are replaced by 0 and 
# the values greater than 0.011059007499999999 are replaced by 0.011059007499999999.
data["AC"] = np.where(data["AC"]<0,0,data["AC"])
data["AC"] = np.where(data["AC"]>0.011059007499999999,0.011059007499999999,data["AC"])

# %%
sn.boxplot(data["AC"],orient = "h")
# Out:
# <Axes: >

# %%
sn.boxplot(data["FM"],orient = "h")
# Out:
# <Axes: >

# %%
Q1 = data["FM"].quantile(0.25)
Q3 = data["FM"].quantile(0.75)
print("FM quantile:",Q1,"and", Q3)
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
print("IQR = Q3-Q1:",IQR)
print("lower_bound:",lower_bound)
print("upper_bound:",upper_bound)
# Out:
# FM quantile: 0.0 and 0.00256657125
# IQR = Q3-Q1: 0.00256657125
# lower_bound: -0.003849856875
# upper_bound: 0.006416428125

# %%
data[data["FM"]<lower_bound]
# Out:
#               LB        AC        FM        UC        DL        DS   DP  ASTV  \
# 229   123.000000  0.002502 -0.480634  0.000000  0.000000  0.000000  0.0  52.0
# 586   120.000000  0.000000 -0.480634  0.005510  0.000000  0.000000  0.0  40.0
# 976   131.000000  0.002275 -0.480634  0.004551  0.004551  0.000000  0.0  42.0
# 996   129.000000  0.006148 -0.480634  0.004098  0.001025  0.000000  0.0  25.0
# 1738  134.000000  0.006121 -0.480634  0.006886  0.003826 -0.001353  0.0  62.0
# 1763  119.965669  0.000000 -0.480634  0.004425  0.011799  0.000000  0.0  59.0
# 1806  143.000000  0.000000 -0.005106  0.001030  0.000000  0.000000  0.0  68.0
#
#       MSTV       ALTV       MLTV  Width  Tendency       NSP
# 229    0.8   1.517448  15.400000   90.0       1.0  1.000000
# 586    1.1   0.000000  14.000000   29.0       0.0  1.000000
# 976    1.0  11.000000   4.490281  102.0       1.0  1.018217
# 996    1.5   0.000000  11.300000   59.0       0.0  1.000000
# ...

# %%
data[data["FM"]>upper_bound]
# Out:
#          LB        AC        FM        UC        DL   DS        DP  ASTV  \
# 12    131.0  0.005076  0.072335  0.007614  0.002538  0.0  0.000000  28.0
# 13    131.0  0.009077  0.222390  0.006051  0.001513  0.0  0.000000  28.0
# 14    130.0  0.005838  0.407840  0.004170  0.005004  0.0  0.000826  21.0
# 15    130.0  0.005571  0.380223  0.004178  0.004178  0.0  0.001393  19.0
# 16    130.0  0.006088  0.441400  0.004566  0.004566  0.0  0.000000  24.0
# ...     ...       ...       ...       ...       ...  ...       ...   ...
# 2083  130.0  0.000000  0.008861  0.007595  0.000000  0.0  0.000000  73.0
# 2099  133.0  0.000000  0.008653  0.004944  0.000000  0.0  0.000000  72.0
# 2100  133.0  0.000000  0.009840  0.004920  0.000000  0.0  0.000000  70.0
# 2101  133.0  0.000000  0.009357  0.008187  0.000000  0.0  0.000000  69.0
# 2121  140.0  0.000000  0.961268  0.007426  0.000000  0.0  0.000000  79.0
#
#         MSTV       ALTV  MLTV  Width  Tendency  NSP
# ...

# %%
print(data["FM"].quantile(0.05))
print(data["FM"].quantile(0.95))
# Out:
# 0.0
# 0.029394801499999998

# %%
# treatment of outliers by replacing the values
# the values lesser than 0 are replaced by 0 and 
# the values greater than 0.029394801499999998 are replaced by 0.029394801499999998.
data["FM"] = np.where(data["FM"]<0,0,data["FM"])
data["FM"] = np.where(data["FM"]>0.029394801499999998,0.029394801499999998,data["FM"])

# %%
sn.boxplot(data["FM"],orient = "h")
# Out:
# <Axes: >

# %%
column_name = 'UC'
sn.boxplot(data[column_name],orient = "h")
Q1 = data[column_name].quantile(0.25)
Q3 = data[column_name].quantile(0.75)
print(column_name, "quantile Q1=:",Q1,"and Q3=", Q3)
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
print("IQR = Q3-Q1:",IQR)
print("lower_bound:",lower_bound)
print("upper_bound:",upper_bound)
data[data[column_name]<lower_bound]
# Out:
# UC quantile Q1=: 0.00185059075 and Q3= 0.006535948
# IQR = Q3-Q1: 0.004685357249999999
# lower_bound: -0.005177445124999999
# upper_bound: 0.013563983874999998
#          LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 793   146.0  0.000388  0.0 -0.014925  0.001940  0.0  0.0  52.0   0.8  32.0
# 1396  142.0  0.000872  0.0 -0.014925  0.004359  0.0  0.0  49.0   0.9  28.0
# 1469  148.0  0.003633  0.0 -0.014925  0.000000  0.0  0.0  36.0   0.8   8.0
# 1868  138.0  0.007143  0.0 -0.014925  0.003571  0.0  0.0  49.0   1.6   0.0
#
#       MLTV  Width  Tendency  NSP
# 793    8.6   72.0       1.0  1.0
# 1396   5.8  114.0       1.0  1.0
# 1469   9.4   45.0       0.0  1.0
# 1868   6.0   92.0       1.0  1.0

# %%
data[data[column_name]>upper_bound]
# Out:
#               LB        AC       FM        UC        DL   DS        DP  ASTV  \
# 134   119.000000  0.001590  0.00000  0.029851  0.000000  0.0  0.000003  58.0
# 543   140.000000  0.000029  0.00000  0.029851  0.000000  0.0  0.000000  53.0
# 917   121.851326  0.000000  0.00000  0.029851  0.000000  0.0  0.001706  33.0
# 1164  131.000000  0.010661  0.00000  0.014925  0.000000  0.0  0.000000  26.0
# 1593  134.000000  0.000000  0.00000  0.029936  0.008086  0.0  0.000000  20.0
# 1671  119.000000  0.003799  0.00076  0.029851  0.000760  0.0 -0.000017  65.0
# 1717  131.000000  0.009857  0.00000  0.030002  0.000896  0.0  0.000000  54.0
# 1902  130.000000  0.005941  0.00000  0.013861  0.011837  0.0  0.000000  57.0
# 1903  130.000000  0.002053  0.00000  0.014374  0.014374  0.0  0.000000  59.0
#
#       MSTV  ALTV  MLTV  Width  Tendency  NSP
# 134    0.5   0.0   7.9   44.0  1.000000  1.0
# 543    0.7   0.0  14.8   84.0  1.000000  1.0
# 917    1.1   8.0   7.2   60.0 -0.003937  1.0
# ...

# %%
print(data[column_name].quantile(0.05))
print(data[column_name].quantile(0.95))
## treatment of outliers by replacing the values
data[column_name] = np.where(data[column_name]<0,0,data[column_name])
data[column_name] = np.where(data[column_name]>0.00927715575,0.00927715575,data[column_name])
sn.boxplot(data[column_name],orient = "h")
# Out:
# 0.0
# 0.00927715575
# <Axes: >

# %%
column_name = 'DL'
sn.boxplot(data[column_name],orient = "h")
Q1 = data[column_name].quantile(0.25)
Q3 = data[column_name].quantile(0.75)
print(column_name, "quantile Q1=:",Q1,"and Q3=", Q3)
IQR = Q3-Q1
lower_bound = Q1-1.5*IQR
upper_bound = Q3+1.5*IQR
print("IQR = Q3-Q1:",IQR)
print("lower_bound:",lower_bound)
print("upper_bound:",upper_bound)
data[data[column_name]<lower_bound]
# Out:
# DL quantile Q1=: 0.0 and Q3= 0.003289474
# IQR = Q3-Q1: 0.003289474
# lower_bound: -0.004934211
# upper_bound: 0.008223685
#               LB        AC   FM        UC        DL   DS        DP  ASTV  \
# 894   144.331585  0.000000  0.0  0.006757 -0.015385  0.0  0.000000  36.0
# 967   133.000000  0.005000  0.0  0.003333 -0.015385  0.0  0.000000  27.0
# 1035  125.000000  0.000000  0.0  0.004040 -0.015385  0.0  0.000000  32.0
# 1218  135.000000  0.000000  0.0  0.006867 -0.015393  0.0  0.000000  54.0
# 1496  132.000000  0.006124  0.0  0.009277 -0.015385  0.0  0.000000  32.0
# 1963  133.000000  0.000000  0.0  0.009277 -0.015385  0.0  0.002281  61.0
#
#       MSTV  ALTV  MLTV  Width  Tendency  NSP
# 894    0.8   2.0  10.4   27.0  0.000000  1.0
# 967    1.7   0.0  20.4   89.0  1.000000  1.0
# 1035   1.0  15.0   6.0   33.0  0.988564  1.0
# 1218   0.5  12.0   9.0   32.0  1.000000  1.0
# 1496   1.2   0.0  13.5   72.0  1.000000  5.0
# 1963   2.8   0.0   0.0   98.0  0.000000  3.0

# %%
data[data[column_name]>upper_bound]
# Out:
#          LB        AC        FM        UC        DL   DS        DP       ASTV  \
# 5     134.0  0.001116  0.000000  0.009277  0.009444  0.0  0.002099  26.000000
# 6     134.0  0.001403  0.000000  0.009277  0.008415  0.0  0.002805  29.000000
# 28    132.0  0.000000  0.029395  0.000834  0.008340  0.0  0.000834  29.000000
# 29    132.0  0.000000  0.029395  0.000000  0.012158  0.0  0.000000  26.000000
# 30    132.0  0.000000  0.029395  0.001702  0.010008  0.0  0.000000  26.487809
# ...     ...       ...       ...       ...       ...  ...       ...        ...
# 2045  128.0  0.000000  0.006222  0.008889  0.009778  0.0  0.000000  63.000000
# 2046  128.0  0.000000  0.006604  0.008491  0.009434  0.0  0.000000  63.000000
# 2047  128.0  0.000000  0.007675  0.006579  0.009868  0.0  0.000000  63.000000
# 2048  128.0  0.000000  0.000000  0.008032  0.010040  0.0  0.000000  63.000000
# 2111  136.0  0.000000  0.001156  0.008696  0.008696  0.0  0.002174  63.000000
#
# ...

# %%
print(data[column_name].quantile(0.05))
print(data[column_name].quantile(0.95))
## treatment of outliers by replacing the values
data[column_name] = np.where(data[column_name]<0,0,data[column_name])
data[column_name] = np.where(data[column_name]>0.008409990624999999,0.008409990624999999,data[column_name])
sn.boxplot(data[column_name],orient = "h")
# Out:
# 0.0
# 0.0084122005
# <Axes: >

# %%
column_name = 'LB'
plt.hist(data[column_name])
# Out:
# (array([241., 173., 185., 249., 287., 202., 199., 184., 163., 243.]),
#  array([119., 122., 125., 128., 131., 134., 137., 140., 143., 146., 149.]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'AC'
plt.hist(data[column_name])
# Out:
# (array([958., 187., 192., 131., 121., 126., 102.,  93.,  62., 154.]),
#  array([0.        , 0.0011059 , 0.0022118 , 0.0033177 , 0.0044236 ,
#         0.0055295 , 0.0066354 , 0.00774131, 0.00884721, 0.00995311,
#         0.01105901]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'FM'
plt.hist(data[column_name])
# Out:
# (array([1624.,  150.,   74.,   59.,   27.,   30.,   24.,   11.,   13.,
#          114.]),
#  array([0.        , 0.00293948, 0.00587896, 0.00881844, 0.01175792,
#         0.0146974 , 0.01763688, 0.02057636, 0.02351584, 0.02645532,
#         0.0293948 ]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'UC'
plt.hist(data[column_name])
# Out:
# (array([371., 161., 147., 184., 251., 255., 215., 203., 152., 187.]),
#  array([0.        , 0.00092772, 0.00185543, 0.00278315, 0.00371086,
#         0.00463858, 0.00556629, 0.00649401, 0.00742172, 0.00834944,
#         0.00927716]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'DL'
plt.hist(data[column_name])
# Out:
# (array([1274.,  154.,   86.,   94.,   94.,   90.,   88.,   54.,   42.,
#          150.]),
#  array([0.        , 0.000841  , 0.001682  , 0.002523  , 0.003364  ,
#         0.004205  , 0.00504599, 0.00588699, 0.00672799, 0.00756899,
#         0.00840999]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'DS'
plt.hist(data[column_name])
# Out:
# (array([   7.,    0.,    0., 2110.,    0.,    3.,    3.,    0.,    0.,
#            3.]),
#  array([-0.00135318, -0.00094723, -0.00054127, -0.00013532,  0.00027064,
#          0.00067659,  0.00108254,  0.0014885 ,  0.00189445,  0.00230041,
#          0.00270636]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'DP'
plt.hist(data[column_name])
# Out:
# (array([   4.,    0.,    0., 1979.,  107.,   26.,    4.,    0.,    0.,
#            6.]),
#  array([-0.00534759, -0.00374332, -0.00213904, -0.00053476,  0.00106952,
#          0.0026738 ,  0.00427808,  0.00588235,  0.00748663,  0.00909091,
#          0.01069519]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'ASTV'
plt.hist(data[column_name])
# Out:
# (array([  5.,   0.,   0., 336., 740., 891., 149.,   0.,   0.,   5.]),
#  array([-63. , -40.5, -18. ,   4.5,  27. ,  49.5,  72. ,  94.5, 117. ,
#         139.5, 162. ]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'MSTV'
plt.hist(data[column_name])
# Out:
# (array([   3.,    0.,    0., 1452.,  616.,   41.,    7.,    0.,    0.,
#            7.]),
#  array([-6.6 , -4.56, -2.52, -0.48,  1.56,  3.6 ,  5.64,  7.68,  9.72,
#         11.76, 13.8 ]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'ALTV'
plt.hist(data[column_name])
# Out:
# (array([   3.,    0.,    0., 1715.,  245.,  125.,   31.,    0.,    0.,
#            7.]),
#  array([-91. , -63.7, -36.4,  -9.1,  18.2,  45.5,  72.8, 100.1, 127.4,
#         154.7, 182. ]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'MLTV'
plt.hist(data[column_name])
# Out:
# (array([   5.,    0.,    0., 1500.,  586.,   27.,    3.,    0.,    0.,
#            5.]),
#  array([-50.7 , -35.49, -20.28,  -5.07,  10.14,  25.35,  40.56,  55.77,
#          70.98,  86.19, 101.4 ]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'Width'
plt.hist(data[column_name])
# Out:
# (array([  5.,   0.,   0., 563., 877., 612.,  64.,   0.,   0.,   5.]),
#  array([-174. , -120.9,  -67.8,  -14.7,   38.4,   91.5,  144.6,  197.7,
#          250.8,  303.9,  357. ]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'Tendency'
plt.hist(data[column_name])
# Out:
# (array([   6.,    0.,    0.,  163.,   33., 1085.,  835.,    0.,    0.,
#            4.]),
#  array([-3. , -2.4, -1.8, -1.2, -0.6,  0. ,  0.6,  1.2,  1.8,  2.4,  3. ]),
#  <BarContainer object of 10 artists>)

# %%
column_name = 'NSP'
plt.hist(data[column_name])
# Out:
# (array([6.000e+00, 0.000e+00, 0.000e+00, 1.651e+03, 1.000e+00, 2.920e+02,
#         1.720e+02, 0.000e+00, 0.000e+00, 4.000e+00]),
#  array([-1.025988 , -0.4233892,  0.1792096,  0.7818084,  1.3844072,
#          1.987006 ,  2.5896048,  3.1922036,  3.7948024,  4.3974012,
#          5.       ]),
#  <BarContainer object of 10 artists>)

# %%
sn.lineplot(x=data["AC"], y = data["LB"]);

# %%
## The above graph indicates a normal FHR as a normal FHR is between 110 - 160.

# %%
sn.lineplot(x=data["UC"], y = data["LB"]);

# %%
sn.lineplot(x=data["UC"], y = data["DL"]);

# %%
## As the deceleration is late its a sign of fetal distress 
## the lower the deceleration the higher the uterine contractions which is sign of fetal distress

# %%
sn.lineplot(x=data["ASTV"], y = data["LB"]);
# the FHR is within normal, ASTV in FHR is from 15 to 85 in the plotted graph

# %%
sn.lineplot(x=data["MSTV"], y = data["LB"]);

# %%
sn.lineplot(x=data["ALTV"], y = data["LB"]);

# %%
sn.lineplot(x=data["MLTV"], y = data["LB"]);

# %%
## avg is 5 to 10bpm in 10 min period and long term is 10 to 25bpm in 10 min period
